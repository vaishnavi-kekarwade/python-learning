# %%
#Topic: Strings & Conditional Statements
#Date:April 2026    
#Key Concepts:indexing, slicing, concatenation, if-elif-else, nested conditions and Practice Questions.

# %%
str1 ="This is a string.\nwhen are creating in python" # to create strings 
str2 ='discipline beings \nwhen comfort ends'
str3 ="""this is a string"""
#escape sequence characters
#basic operation, concatenation, length of string
print(str1)
print(str2)
# Out:
# This is a string.
# we are creating in python
# discipline beings
# when comfort ends

# %%
#basic operation, concatenation, length of string
str1 ="move on "
print(len(str1))
str2 ="carry on"
print(len(str2))
final_str= str1 +" "+str2
print(final_str)
print(len(final_str))
# Out:
# 8
# 8
# move on  carry on
# 17

# %%
#indexing 
str ="Discipline"
print(str[4])
print(str[0])
# Out:
# i
# D

# %%
#slicing is accessing parts of a string
str ="Discipline"
print(str[0:4])
print(str[6:len(str)])
print(str[:10]) #[0:10]
print(str[0:])
# Out:
# Disc
# line
# Discipline
# Discipline

# %%
#negative index
str ="management"
print(str[-10:-4])
# Out:
# manage

# %%
#Store your full name as a string. Print only your first name using slicing.
str = "Vaishnavi Kekarwade"
print(str[0:9])

#Print the last character of your name using negative indexing
print(str[-11:-9])
# Out:
# Vaishnavi
# i

# %%
#Join your city and state with a comma using concatenation.
str1 ="Nagpur"
str2 = "Maharashtra"
final_str = str1 +","+str2
print(final_str)
# Out:
# Nagpur,Maharashtra

# %%
#Print your name and college on two separate lines using \n ,in one print statement only.
str1 = 'Vaishnavi Kekarwade\nInstitute of Science'
print(str1)
# Out:
# Vaishnavi Kekarwade
# Institute of Science

# %%
# from my understanding
#Indexing means accessing one specific character using its position number.

#n slicing we slice part from word like if we want only four characters we can do it from any order backward forward middle.

#Slicing means extracting a part of the string by giving a start and end position.
#We can slice from the front, middle, or use negative numbers to slice from the back.

#indexing = one character --> name[1]
#slicing = multiple character-- name[0:9]

# %%
#string functions
str = " I am studying python"
print(str.endswith("on"))

print(str.capitalize())

print(str.replace("python" , "datascience"))

print(str.find("s"))
print(str.find("am"))
print(str.find("z"))

print(str.count("t"))
# Out:
# True
#  i am studying python
#  I am studying datascience
# 6
# 3
# -1
# 2

# %%
#Q writ a program users first name and print its length

name =input("enter your name:")
print("length of your name is",len(name))
# Out:
# enter your name: archana
# length of your name is 7

# %%
#Q write a program to find the occurrence of $ in a string
str = "the magic $ you are looking for $$$ is in the work you are avoiding$$"
print(str.count("$"))
# Out:
# 6

# %%
name = "vaishnavi kekarwade"
print(name.replace("a","o"))
# Out:
# voishnovi kekorwode

# %%
#conditional statements
#if-elif-else (syntax)

# %%
age = 24
if (age>=18):
    print("can vote")
    print("can drive")
# Out:
# can vote
# can drive

# %%
light = "yellow"

if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light =="yellow"):
    print("Look")

print("end of code")
# Out:
# Look
# end of code

# %%
num = 5

if(num>2):
    print("greater than 2")
elif(num>3):
    print("greater than 3")
# Out:
# greater than 2

# %%
light ="pink"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light =="yellow"):
    print("Look")
else:
   print("light is broken")
print("end of code")
# Out:
# light is broken
# end of code

# %%
age = 17
if(age>=18):
    print("can vote") #indentation  proper spacing is very important
else:  # it will check its true first
    print("cannot vote")
# Out:
# cannot vote

# %%
#conditional statements
marks = (int(input("enter  student marks:")))

if(marks>=90):
    grade ="A"
elif(marks >=80 and marks<90):
    grade ="B"
elif(marks >=70 and marks<80):
    grade ="C"
else:
    grade="D"
print("grade of the student -->",grade)
# Out:
# enter  student marks: 85
# grade of the student --> B

# %%
#nesting
age = 19

if (age>=21):
    if (age>=20):
        print("cannot drive")
    else:
        print("can drive")
else:
    print("cannot drive")
# Out:
# cannot drive

# %%
#write a program  to check if a number entered by the user is odd or even
# number%2==0 remainder is always zero is even number

num = 16
rem = num % 2
if (rem==0):
    print("even")
else:
    print("odd")
# Out:
# even

# %%
a=(int(input("enter your number")))
b=(int(input("enter your number")))
c=(int(input("enter your number")))
if (a>b and a>c):
   print("first number is greatest",a)
elif(b>c):
  print("second number is greatest",b)
else:
    print("third is largest", c)
# Out:
# enter your number 3
# enter your number 4
# enter your number 6
# third is largest 6

# %%
# PRACTICE QUESTION write a program if a number 7 or not
x = (int(input("enter number :")))
if(x % 7 ==0):
    print("multiple of 7")
else:
    print("not a multiple")
# Out:
# enter number : 49
# multiple of 7

# %%
#Take a sentence as input from user and print it in uppercase
text = input(" write your sentence")
print(text.upper())
# Out:
#  write your sentence the tree is known by its fruits
# THE TREE IS KNOWN BY ITS FRUITS

# %%
#Take a word as input and print how many times the letter "a" appears in it
a = input("write your word")
print(a.count(a))
# Out:
# write your word motivation
# 1

# %%
#Take a person's full name as input and print only their last name using slicing
name = input("write your full name")
result =(name[9:19])
print("sliced result:", result)
# Out:
# write your full name vaishnavi kekarwade
# sliced result:  kekarwade

# %%
#Take two words s input and join them with a - in between
words= input("your word")
print("-".join(words))
# Out:
# your word DATA SCIENCE
# D-A-T-A- -S-C-I-E-N-C-E

# %%
#Take a sentence as input and replace every space with an underscore _
sentence = input("write your sentence")
print("_".join(sentence))
# Out:
# write your sentence the goal of mankind is knowledge
# t_h_e_ _g_o_a_l_ _o_f_ _m_a_n_k_i_n_d_ _i_s_ _k_n_o_w_l_e_d_g_e

# %%
'''conditional statements'''
#Take a number as input print "positive", "negative" or "zero"
num = int(input( "enter your number"))
if(num>0):
    print("positive")
elif(num<0):
    print("negtive")
else:
    print("zero")
# Out:
# enter your number 0
# zero

# %%
#Take a username as input  if it equals "admin" print "Welcome admin!" else print "Access denied"
#take input
username = input("enter username")

# checking condition and print 
if username =="admin":
    print("Welcome admin!")
else:
    print("Access denied")
# Out:
# enter username welcome user
# Access denied

# %%
#Take marks as input  pass if marks >= 40, fail if below 40
marks = (int(input("enter marks")))
if (marks >= 40):
    print("pass")    
elif (marks <= 40):
    print("fail")
# Out:
# enter marks 50
# pass

# %%
#Take a number as input  print "fizz" if divisible by 3, "buzz" if divisible by 5, "fizzbuzz" if divisible by both
num = (int(input("write your number:")))
#check  for 5 and 3
if num%3==0 and num%5==0:
    print("fizzbuzz")
elif(num%3==0): 
    print("fizz")
elif(num%5==0):
    print("buzz")
#else:
    #print(num)  # else condition to print the number if not divisible
# Out:
# write your number: 15
# fizzbuzz
