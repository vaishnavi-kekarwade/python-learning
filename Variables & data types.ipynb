# %%
#first program
print("Vaishnavi Kekarwade") #string print as same as what is written in parenthesis
print("My age is 21")
print("My name is vaishnavi Kekarwade." ,"And my age is 21.")
print(21)
print(2026-2004)
# Out:
# Vaishnavi Kekarwade
# My age is 21
# My name is vaishnavi Kekarwade. And my age is 21.
# 21
# 22

# %%
#first program
print("Vaishnavi Kekarwade") #string print as same as what is written in parenthesis
print("My age is 21")
print("My name is vaishnavi Kekarwade." ,"And my age is 21.")
print(21)
print(2026-2004)

# %%
#Variables is name given to a memory location in our program
#variable name should simple short and meaningful.
#age , name , price 
name ="Vaishnavi" # variable = value 
age = 21 # 21 is storing to age, assignment operator
price = 21.00
#print("name") # with double quotes gives same value.
print(name)
print(age)
print(price)

print("my name is :",name)
print("my age is :",age)
print("the price is:",price)

age2 = age # use assignment operator
print(age2)

name2 = name
print(name)
# Out:
# Vaishnavi
# 21
# 21.0
# my name is : Vaishnavi
# my age is : 21
# the price is: 21.0
# 21
# Vaishnavi

# %%
print(type(name)) # data-types ---> integers, string, float,boolean ,None
print(type(age))
print(type(price))

name1 = "VK"
name2 ='VK'
name3 = '''VK'''

age = 23
old = False
a = None
print(type(old))
print(type(a))
#None 
#a = none#no values is stored
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
#keywords are reserved words in python #case-sensitive
#None , False, True, and , as , break, if , while, return, except , else, is , in,not, pass,  for, try,import,if,class,def,del
#Print sum
'''this is a basic program'''
a = 2026
b = 2004
sum = a+b
print(sum)

diff = a-b
print(diff)
# Out:
# 4030
# 22

# %%
#comments in python 
#single comment we can write
#print("hello world") it will not execute

# %%
#type of operators--> Arithmetic , Relational, comparison , assignment ,

# arithmetic
a = 20
b = 4
print(a-b)
print(a+b)
print(a*b)
print(a/b) #answer will be a float value
print(a%b) #modulo  to find out remainder
print(a**b)# a to the power b  a^b
# Out:
# 16
# 24
# 80
# 5.0
# 0
# 160000

# %%
# relational operator return will true or false
a = 50
b = 20
print(a==b) 
print(a!=b)
print(a>b)
print(a>=b)
print(a<=b)
print(a<b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
#assignment operator
num = 20
#num = num+20 
#num +=20
#num -=20
#num *=20
#num /=20
#num %=20
num **=20
print("num:",num)
# Out:
# num: 104857600000000000000000000

# %%
#logical operator
print(not False)
print(not True)
# Out:
# True
# False

# %%
a = 10
b = 5
#print(not False)
print(not(a>b))
val1 = True
val2 = True
print("and operator :", val1 and val2) #it should be true

val1 = True
val2 = False
print("and operator :",val1 and val2)
print("or operator :", val1 and val2)
print("OR operator :", (a==b) or (a>b)) # dono mai se ek bhi value true ho it will return true
# Out:
# False
# and operator : True
# and operator : False
# or operator : False
# OR operator : True

# %%
#type conversion , type casting --> automatically , manually. respectively
a = 2 
b  = 2.2
sum = a+b# 2.0 + 2.2 = 4.2
print(sum)
# Out:
# 4.2

# %%
 a = "2" #only concatenate string (not "float") to string
 b = 2.2
 print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 a = "2"
#       2 b = 2.2
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "float") to str

# %%
#typecasting
#a = int("2")
a = float("2")
b = 2.2
print(type(a))
print(a+b)
# Out:
# <class 'float'>
# 4.2

# %%
a = 3.14
a = str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
#input in python
input("enter your name:")
# we can store in variable
print("Hi",name)
# Out:
# enter your name: vaishnavi
# Hi Vaishnavi

# %%
name = input("enter your name")
age = input("enter your age")
marks = input("enter marks:")

print("Hi",name)
print(" age =",age)
print("marks=",marks)
# Out:
# enter your name vaishnavi
# enter your age 21
# enter marks: 50
# Hi vaishnavi
#  age = 21
# marks= 50

# %%
# WAP to input 2 numbers and print their sum

number1 = int(input("enter your number1"))
number2= int(input("enter your number2"))
print(number1+number2)
# Out:
# enter your number1 11
# enter your number2 11
# 22

# %%
firstnumber = int(input("enter your first number"))
secondnumber = int(input("enter your second number"))
print("sum=",firstnumber + secondnumber)
# Out:
# enter your first number 11
# enter your second number 11
# sum= 22

# %%
#Write a program side of a square and print its area
side = int(input("side*side"))
print(side*side)
# Out:
# side*side 2
# 4

# %%
side = int(input("enter square side:"))
print("area=", side**2)
# Out:
# enter square side: 11
# area= 121

# %%
#write a program input 2 floating point numbers and print their average
a= int(input("enter your number"))
b= int(input("enter your number"))
print("avg=", (a+b)/2)
# Out:
# enter your number 20
# enter your number 4
# avg= 12.0

# %%
#write a program to input 2 int numbers , a and b
#print true if  a is greater a >=b, if not print False
a = int(input("enter your number"))
b = int(input("enter your number"))
print(a>=b)
# Out:
# enter your number 10
# enter your number 5
# True
